# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import warnings
import statsmodels.api as sm
import math
import seaborn as sns
import time 
import random
from scipy.interpolate import LSQUnivariateSpline as Spline
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pickle

# %%
# Load data
data = pd.read_csv("../data/full_training_data.csv")
data.head()
# Out:
#    Sold_Price  Make   Mileage  Exterior Color  Interior Color  Gears  \
# 0    356000.0    60      70.0               5               1    6.0
# 1     12100.0     8  138200.0              13               1    5.0
# 2     42000.0    76   21700.0               1               1    8.0
# 3     26250.0     8   91600.0               5               6    6.0
# 4     58500.0    24   77800.0              13               1    7.0
#
#    Engine_Displacement_L  Title Status_Bill of Sale  Title Status_Clean  \
# 0                    4.0                      False                True
# 1                    2.5                      False                True
# 2                    3.0                      False                True
# 3                    3.0                      False                True
# 4                    4.3                      False                True
#
#    Title Status_Exceeds Mechanical Limits  ...  Engine_Cylinders_I4  \
# ...

# %%
# Data Splitting

X = data.drop(columns = ["Sold_Price"])
y = data['Sold_Price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, 
                                                    random_state=42)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

rf_model.fit(X_train, y_train)

y_train_pred = rf_model.predict(X_train) # Predict on the data it studied
y_test_pred = rf_model.predict(X_test)   # Predict on data it has never seen

r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f"Training R2: {r2_train:.2f}")
print(f"Test R2:     {r2_test:.2f}")
# Out:
# Training R2: 0.97
# Test R2:     0.78

# %%
# Saving model and columns
artifacts = {
    "model": rf_model,
    "training_columns": X_train.columns.tolist()
}

with open('../deployment/model_artifacts_001.pkl', 'wb') as f:
    pickle.dump(artifacts, f)
