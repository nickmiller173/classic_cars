# %%
import json
import pandas as pd

# Load data
data = pd.read_csv("../data/full_training_data.csv")
data.head()
# Out:
#    Sold_Price  Bids  Views  Watchers              Auction_Date  Make  \
# 0     66000.0    26   6277     447.0  Feb 18, 2026 1:48 PM MST    28
# 1     51000.0    22  11947     962.0  Feb 18, 2026 1:46 PM MST     5
# 2     17000.0    49  10966     662.0  Feb 18, 2026 1:38 PM MST    85
# 3     29888.0    43  16565     957.0  Feb 18, 2026 1:36 PM MST     9
# 4     29995.0    30   8501     585.0  Feb 18, 2026 1:33 PM MST    73
#
#     Mileage  Exterior Color  Interior Color  \
# 0   17600.0              13               1
# 1   41000.0               2               0
# 2  310800.0               6               8
# 3       NaN              11               1
# 4       NaN               6               1
#
#                                           Highlights  ... Engine_Cylinders_I6  \
# 0  this... is a 2017 ford shelby f-150 supercrew ...  ...               False
# 1  this... is a 2009 audi r8 coupe, finished in j...  ...               False
# 2  this… is a 2004 toyota land cruiser, finished ...  ...               False
# 3  this... is a 2007 bmw m5, finished in silverst...  ...               False
# 4  this... is a 1998 rover mini, finished in brit...  ...               False
#
#   Engine_Cylinders_V10 Engine_Cylinders_V12 Engine_Cylinders_V6  \
# 0                False                False               False
# 1                False                False               False
# 2                False                False               False
# 3                 True                False               False
# 4                False                False               False
#
#   Engine_Cylinders_V8 Engine_Cylinders_W12 Engine_Cylinders_W8  \
# 0                True                False               False
# 1                True                False               False
# 2                True                False               False
# 3               False                False               False
# 4               False                False               False
#
#    mod_status_light_mod  mod_status_unknown_mod  Model_Target_Encoded
# 0                 False                    True          43545.115385
# 1                 False                    True         108084.769231
# 2                 False                    True          20235.769231
# 3                 False                   False          29194.666667
# 4                  True                   False          29995.000000
#
# [5 rows x 84 columns]

# %%
import pandas as pd

def check_distributions(file_path):
    # Load the dataset
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print("Error: File not found.")
        return

    print(f"--- Dataset Summary: {len(df)} rows, {len(df.columns)} columns ---\n")

    for col in df.columns:
        print(f"### Column: {col} ###")
        
        # 1. Print Value Counts (Top 10 for brevity)
        print("Top 10 Value Counts:")
        print(df[col].value_counts().head(10))
        
        # 2. Check Distribution/Summary Stats
        if pd.api.types.is_numeric_dtype(df[col]):
            # For numbers: Mean, Median, Min, Max
            print("\nNumeric Distribution:")
            print(df[col].describe().to_string())
        else:
            # For categories: Unique count and mode
            print("\nCategorical Distribution:")
            print(f"Unique values: {df[col].nunique()}")
            print(f"Most frequent: {df[col].mode()[0] if not df[col].mode().empty else 'N/A'}")
            
        print("-" * 30 + "\n")

# Usage
check_distributions("../data/full_training_data.csv")
# Out:
# --- Dataset Summary: 4319 rows, 84 columns ---
#
# ### Column: Sold_Price ###
# Top 10 Value Counts:
# Sold_Price
# 15000.0    45
# 20000.0    33
# 14000.0    32
# 16000.0    31
# 13000.0    30
# 18000.0    29
# 27000.0    29
# 30000.0    28
# 25000.0    28
# 15250.0    28
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319.000000
# mean      30822.467006
# std       35395.244182
# min        1020.000000
# 25%       11084.000000
# 50%       20000.000000
# 75%       37000.000000
# max      475000.000000
# ------------------------------
#
# ### Column: Bids ###
# Top 10 Value Counts:
# Bids
# 26    144
# 28    127
# 21    125
# 31    122
# 23    121
# 33    120
# 29    120
# 22    119
# 30    117
# 24    112
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean       30.767076
# std        14.648306
# min         1.000000
# 25%        20.000000
# 50%        29.000000
# 75%        40.000000
# max       150.000000
# ------------------------------
#
# ### Column: Views ###
# Top 10 Value Counts:
# Views
# 7691     3
# 7309     3
# 10400    3
# 12040    3
# 6904     3
# 5800     3
# 6136     3
# 7308     3
# 10886    3
# 10264    3
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319.000000
# mean      12071.269044
# std        8282.071295
# min        2560.000000
# 25%        7493.000000
# 50%       10098.000000
# 75%       14242.500000
# max      230668.000000
# ------------------------------
#
# ### Column: Watchers ###
# Top 10 Value Counts:
# Watchers
# 323.0    2
# 447.0    1
# 662.0    1
# 962.0    1
# 585.0    1
# 426.0    1
# 512.0    1
# 957.0    1
# 271.0    1
# 393.0    1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count     33.000000
# mean     529.454545
# std      183.652370
# min      250.000000
# 25%      426.000000
# 50%      512.000000
# 75%      608.000000
# max      962.000000
# ------------------------------
#
# ### Column: Auction_Date ###
# Top 10 Value Counts:
# Auction_Date
# Feb 13, 2026 1:14 PM MST     3
# Oct 21, 2025 10:49 AM MST    3
# Jan 20, 2026 1:39 PM MST     3
# Feb 17, 2026 12:15 PM MST    3
# Dec 31, 2025 1:50 PM MST     3
# Dec 23, 2025 1:50 PM MST     3
# Oct 24, 2025 12:26 PM MST    2
# Jan 27, 2026 1:14 PM MST     2
# Oct 27, 2025 11:02 AM MST    2
# Jan 27, 2026 1:46 PM MST     2
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 4061
# Most frequent: Dec 23, 2025 1:50 PM MST
# ------------------------------
#
# ### Column: Make ###
# Top 10 Value Counts:
# Make
# 9     685
# 68    472
# 55    377
# 28    252
# 15    246
# 85    245
# 5     225
# 45    119
# 44    117
# 32    108
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean       42.038203
# std        27.680666
# min         0.000000
# 25%        13.000000
# 50%        44.000000
# 75%        68.000000
# max        92.000000
# ------------------------------
#
# ### Column: Mileage ###
# Top 10 Value Counts:
# Mileage
# 70000.0    10
# 26600.0     9
# 13300.0     9
# 2300.0      8
# 97300.0     8
# 5700.0      8
# 84500.0     8
# 88100.0     8
# 50500.0     8
# 19800.0     8
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      3966.000000
# mean      71644.869138
# std       51807.769962
# min          22.000000
# 25%       32525.000000
# 50%       64000.000000
# 75%       98600.000000
# max      441900.000000
# ------------------------------
#
# ### Column: Exterior Color ###
# Top 10 Value Counts:
# Exterior Color
# 1     921
# 13    655
# 11    540
# 5     510
# 2     504
# 10    423
# 8     409
# 6     145
# 14     68
# 7      55
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        6.726326
# std         4.553844
# min         0.000000
# 25%         2.000000
# 50%         7.000000
# 75%        11.000000
# max        14.000000
# ------------------------------
#
# ### Column: Interior Color ###
# Top 10 Value Counts:
# Interior Color
# 1     2301
# 5      605
# 8      536
# 0      267
# 10     162
# 12     119
# 3      105
# 2       90
# 13      53
# 11      38
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        3.372540
# std         3.505556
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         5.000000
# max        14.000000
# ------------------------------
#
# ### Column: Highlights ###
# Top 10 Value Counts:
# Highlights
# this... is a 2021 bmw x7 m50i, finished in carbon black metallic with a tartufo interior. the attached carfax vehicle history report shows no accidents or mileage discrepancies in this bmw’s past. according to the build sheet provided in the gallery, notable factory equipment includes the executive, driver assistance professional, and cold weather packages, 22-inch style 758 wheels, an m sport differential, merino leather upholstery, power-adjustable, heated, ventilated, and massaging front seats, and a harman kardon surround sound system. the seller reports no notable modifications. the x7 m50i was introduced as the high-performance variant of bmw’s flagship suv, combining luxury and capability in a three-row configuration. it features advanced technology and a powerful engine, positioning it as a strong contender in the full-size luxury suv segment. the x7 m50i is notable among enthusiasts for delivering m performance dynamics in a spacious and versatile package. power comes from a 4.4-liter twin-turbocharged v8, rated at 523 horsepower and 553 lb-ft of torque. output is sent to the four wheels via an 8-speed automatic transmission.                                                                                                                                                                                                                                                              2
# this… is a 1989 bmw alpina b10 3.5, finished in lazer blue metallic with a natur interior. this alpina b10 3.5 was built by sytner uk. reportedly only 80 rhd b10s were produced at this factory, and the alpina plaque shows that this b10 is number 8257. the seller reports that this alpina has received a g260 5-speed manual transmission swap. additional notable modifications reported by the seller include an e28 m5 clutch and flywheel, an alpine head unit, an aftermarket shift surround, and a hella matrix third brake light. a partial list of notable equipment reported by the seller includes a power-operated sunroof, leather upholstery, power-adjustable front seats, a leather-wrapped steering wheel, and air conditioning. based on the e34 535i, the alpina b10 3.5 received comprehensive performance-focused modifications from german tuner-turned-manufacturer alpina. they upgraded the 3.5-liter inline-six with bespoke internals, revised engine management, and freer-flowing exhaust, paired with suspension, braking, and aerodynamics enhancements tailored for autobahn stability. subtle alpina styling, numbered production, and exquisite craftsmanship make it one of the earliest examples of the modern executive super-sedan formula. power comes from a 3.5-liter inline-6 engine, rated at 254 horsepower and 238 lb-ft of torque. output is sent to the rear wheels via a 5-speed manual transmission.    2
# this... is a 1984 bmw 318i coupe, finished in delphin with a black and gray interior. this 318i features the desirable 5-speed manual transmission. although starting in 1990 and containing several gaps, the attached carfax vehicle history report shows that this bmw has been registered in california and oregon for the duration of the report. according to the build sheet provided in the gallery, notable factory equipment includes 14-inch style 13 wheels, a manually operated sunroof, cloth upholstery, rear pop-out windows, and air conditioning, notable modifications reported by the seller are limited to a continental head unit. though the first-generation 3 series was already quite an accomplished machine, the legend really began with the debut of the e30 in 1982. offering a compelling blend of quality, style, practicality, and driver involvement, the e30 set the tone for the next four decades and five generations of the venerable 3, and today remains among the most sought-after of all thanks to its compact footprint, classic good looks, and outstanding driving dynamics. power comes from a 1.8-liter inline-4, rated at about 101 horsepower and 103 lb-ft of torque. output is sent to the rear wheels via a 5-speed manual transmission.                                                                                                                                                               2
# this… is a 2017 audi q7 prestige, finished in tofane white crystal effect with a rock gray interior. the attached carfax vehicle history report shows no mileage discrepancies in this q7’s past. according to the build sheet provided in the gallery, notable factory equipment includes the prestige package, a panoramic sunroof, heated second-row seats, and folding third-row seats. the seller reports no notable modifications. this audi q7 features the legendary quattro all-wheel-drive system and is based on the venerable vw platform shared by the bentley bentayga, lamborghini urus, and porsche cayenne; it incorporates extensive use of aluminum alloy and makes the car lighter than the prior, first-generation model. power comes from a 3.0-liter supercharged v6, rated at 333 horsepower and 325 lb-ft of torque. output is sent to all four wheels via an 8-speed automatic transmission and audi's quattro permanent all-wheel drive system.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# this… is a 2007 bentley continental gt diamond series, finished in dark sapphire with a magnolia and nautic interior. the attached carfax vehicle history report shows no accidents or mileage discrepancies in this continental’s past. it also shows that this bentley has been registered to two owners since new. according to the build sheet provided in the gallery, notable factory equipment includes 20-inch wheels, adaptive air suspension, carbon ceramic brakes, diamond-quilted leather upholstery, and heated front seats. notable modifications reported by the seller are limited to a beltronics stir radar detector system. the bentley continental gt was unveiled in 2003 for the 2004 model year, with the gtc convertible following in 2006. it was bentley's first car to launch under the ownership of the volkswagen group and allowed bentley to mass-produce the continental gt and reach a wider customer base upon launch. journalists praised the new continental gt for its build quality, comfort, and performance. bentley reportedly produced 400 diamond series examples globally to commemorate 60 years of production at the bentley crewe factory in cheshire, england. power comes from a 6.0-liter twin-turbocharged w12, rated at 552 horsepower and 479 lb-ft of torque. output is sent to the four wheels via a 6-speed automatic transmission.                                                                  2
# this... is a 2009 bmw x6 xdrive50i, finished in space grey metallic with a black interior. the attached carfax vehicle history report lists no accidents or mileage discrepancies in this x6's past. according to the build sheet provided in the gallery, notable factory equipment includes the sport package, soft-close doors, heated and ventilated front seats, heated rear seats, a heated steering wheel, 4-zone automatic climate control, and a head-up display. notable modifications reported by the selling dealer are limited to black bmw wheel center cap emblems. bmw released the first-generation x6 for the 2008 model year. known as the e71 internally, it was a swoopier evolution of the x5 marketed as a sports activity coupe. it touts over 27 cubic feet of cargo capacity, which increases to nearly 60 cubic feet with the rear seats folded. although production on the e71 ended in 2014, the x6 continues to be produced today. power comes from a twin-turbocharged 4.4-liter v8, rated at 400 horsepower and 450 lb-ft of torque. output is sent to all four wheels via an 8-speed automatic transmission and bmw's xdrive permanent all-wheel drive system.                                                                                                                                                                                                                                                               2
# this... is a 2014 bmw z4 sdrive28i, finished in jet black with a black interior. the attached carfax vehicle history report indicates no accidents or mileage discrepancies in this z4’s past; it also shows southern ownership since new. according to the window sticker provided in the gallery, notable factory equipment includes the sport package, a power-retractable hardtop, power-adjustable front seats, and comfort access keyless entry. the seller reports no notable modifications. referred to as the e89 internally, the second-generation z4 advanced the bmw roadster with aesthetic, mechanical, and technological updates. it was the first bmw z model with a retractable hardtop roof, eliminating the differentiation between coupe and roadster variants. power comes from a 2.0-liter turbocharged inline-4, rated at 240 horsepower and 260 lb-ft of torque. output is sent to the rear wheels via an 8-speed automatic transmission.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             2
# this... is a 2015 porsche cayenne turbo, finished in rhodium silver metallic with a saddle brown interior. the attached carfax vehicle history report shows no mileage discrepancies in this cayenne’s past; it also shows nevada registrations since new. according to the build sheet provided in the gallery, notable factory equipment includes the sport chrono and carbon fiber interior packages, 21-inch 911 turbo design wheels, soft close doors, adaptive cruise control with porsche active safe (pas), and porsche entry & drive. the selling dealer reports no notable modifications. the second-generation cayenne turbo was introduced for the 2011 model year and brought significant improvements in performance, technology, and luxury over its predecessor. as porsche’s flagship suv, it is designed to combine sports car dynamics with everyday practicality and comfort. the cayenne turbo remains popular among enthusiasts for its powerful engine and advanced features. power comes from a 4.8-liter twin-turbocharged v8, rated at 520 horsepower and 553 lb-ft of torque. output is sent to all four wheels via an 8-speed automatic transmission.                                                                                                                                                                                                                                                                             2
# this... is a 2007 porsche 911 carrera 4s coupe, finished in slate grey metallic with a black interior. the attached carfax vehicle history report indicates no mileage discrepancies in this 911’s past. it also shows registrations in california since new. according to the build sheet provided in the gallery, notable factory equipment includes a speed-activated rear spoiler, a power sunroof, full leather upholstery, heated front seats, and a bose sound system. notable modifications reported by the seller include 19-inch fifteen52 sector rsr wheels, soul performance downpipes, csf aluminum radiators, bc racing coilovers, and an apple carplay head unit. the 997-generation 911 launched for 2005 with a more powerful flat-6 than the outgoing model, oval headlights, and an upgraded interior. by combining retro and modern design cues in a water-cooled 911, it was instantly beloved among enthusiasts — and it presents a compelling package for those looking for a smaller and lighter 911 from the modern era. power comes from a 3.8-liter flat-6, rated at 355 horsepower and 295 lb-ft of torque. output is sent to all four wheels via a 5-speed tiptronic s automatic transmission.                                                                                                                                                                                                                                   2
# this... is a 2004 mercedes-benz sl55 amg, finished in designo graphite with a black interior. the attached carfax vehicle history report shows no accidents or mileage discrepancies in this sl55’s past. notable factory equipment reported by the seller includes active body control suspension, a power-folding hardtop, leather upholstery, heated and ventilated seats, and a bose sound system. notable modifications reported by the seller include a rennsport tuning tune, an sl65 amg front bumper, and 19-inch multi-piece amg wheels. called r230 internally, the first new sl of the 21st century made its debut for 2003 as a replacement for the venerable r129 model. it was appreciably quicker and far more advanced than its predecessor, it ditched the boxy lines for a sleeker and more rounded design that was aligned with the rest of the mercedes-benz range, and it came standard with a power-retractable hardtop. production ended in 2011. power comes from a 5.4-liter supercharged v8, rated at 493 horsepower and 516 lb-ft of torque in stock form. due to the tune performed to this sl55, it likely produces more power, but a dyno sheet was not provided to confirm. output is sent to the rear wheels via a 5-speed automatic transmission.                                                                                                                                                                           2
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 4271
# Most frequent: this... is a 1978 lincoln continental mark v, finished in polar white with a chamois interior. a partial list of notable currently installed equipment reported by the seller includes 15-inch wheels, opera windows, a vinyl roof panel, cloth upholstery, air conditioning, and cruise control. stretching 230 inches long, the continental mark v released for 1977 was positioned in the heart of the personal luxury coupe segment. it featured stately styling characterized by concealed headlights, an upright grille, and a wheel-shaped insert in the trunk lid, and it offered a spacious interior with plush seats. mark v production ended after the 1979 model year, and the model was replaced by the much smaller mark vi. power comes from a 460-cubic-inch v8, rated at about 210 horsepower and 357 lb-ft of torque. output is sent to the rear wheels via a 3-speed automatic transmission.
# ------------------------------
#
# ### Column: Equipment ###
# Top 10 Value Counts:
# Equipment
# a partial list of notable equipment reported by the seller includes: limited-slip differential power-operated soft top leather upholstery digital instrument cluster air conditioning cruise control                                                                                                                                                                                                                                                                                                                                                                                                3
# a build sheet is provided in the photo gallery, and a partial list of notable equipment reported by the selling dealer includes: premium package (heated and ventilated front seats, heated rear seats, intuitive parking assist) 18-inch wheels power sunroof leather upholstery genuine wood interior trim power trunk closer                                                                                                                                                                                                                                                                     2
# a build sheet is provided in the photo gallery, and a partial list of notable equipment reported by the seller includes: speed-activated rear spoiler power sunroof full leather upholstery power-adjustable and heated front seats bose sound system                                                                                                                                                                                                                                                                                                                                               2
# a partial list of notable equipment reported by the seller includes: limited-slip differential power-retractable soft top leather upholstery air conditioning push-button start digital instrument cluster                                                                                                                                                                                                                                                                                                                                                                                          2
# a partial list of notable equipment reported by the seller includes: fog lights red brake calipers leather upholstery heated and power-adjustable front seats automatic climate control bose sound system                                                                                                                                                                                                                                                                                                                                                                                           2
# a build sheet is provided in the photo gallery, and a partial list of notable equipment reported by the seller includes: executive package (panoramic sky lounge led roof, heated and cooled cupholders, glass controls) drivers assistance professional package (extended traffic jam assistant, active driving assistant pro) cold weather package (front and rear heated seats, 5-zone automatic climate control) 22-inch style 758 wheels m sport differential merino leather upholstery power-adjustable, heated, ventilated, and massaging front seats harman kardon surround sound system    2
# a partial list of notable equipment reported by the seller includes: pop-up headlights tilt steering column power windows power locks air conditioning cruise control                                                                                                                                                                                                                                                                                                                                                                                                                               2
# a partial list of notable equipment reported by the seller includes: 15-inch wheels rear transaxle pop-up headlights power sunroof power-operated windows                                                                                                                                                                                                                                                                                                                                                                                                                                           2
# a partial list of notable equipment reported by the selling dealer includes: 18-inch turbo look wheels power-operated soft top leather upholstery power-adjustable front seats automatic climate control cruise control                                                                                                                                                                                                                                                                                                                                                                             2
# a build sheet is provided in the photo gallery, and a partial list of notable equipment reported by the seller includes: prestige package (20-inch wheels, heated and ventilated front seats, bose sound system, head-up display, audi connect, audi side assist, and more) panoramic sunroof leather upholstery heated second-row seats folding third-row seats 4-zone climate control                                                                                                                                                                                                             2
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 4246
# Most frequent: a partial list of notable equipment reported by the seller includes: limited-slip differential power-operated soft top leather upholstery digital instrument cluster air conditioning cruise control
# ------------------------------
#
# ### Column: Modifications ###
# Top 10 Value Counts:
# Modifications
# notable modifications reported by the seller include: pioneer head unit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           11
# notable modifications reported by the seller include: black kidney grilles                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         5
# notable modifications reported by the seller include: kenwood head unit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            4
# notable modifications reported by the seller include: black finish on wheels                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       4
# notable modifications reported by the selling dealer include: pioneer head unit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    4
# notable modifications reported by the seller include: kenwood touchscreen head unit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                2
# notable modifications reported by the seller include: beltronics stir radar detector system                                                                                                                                                                                                                                                                                                                                                                                                                                                                        2
# notable modifications reported by the seller include: custom exhaust system bc racing adjustable coilovers "eject" 12v outlet cover                                                                                                                                                                                                                                                                                                                                                                                                                                2
# notable modifications reported by the seller include: rear badges deleted                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2
# notable modifications reported by the seller include: engine: def and egr delete aftermarket exhaust system bully dog ecu tune (recalibrates speedometer for larger tires) wheels, tires, and suspension: 20-inch fuel wheels 37-inch tires 7-to-9-inch fabtech adjustable suspension lift exterior: go rhino steel bumpers 15,000-pound winch side steps black chevrolet "bowtie" emblems aftermarket grille underglow train horn light bars auxiliary driving lights aftermarket taillights aftermarket headlights electronics: digital gauge monitor device     2
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 2576
# Most frequent: notable modifications reported by the seller include: pioneer head unit
# ------------------------------
#
# ### Column: Known Flaws ###
# Top 10 Value Counts:
# Known Flaws
# some chips on the front end                                             8
# some exterior chips                                                     5
# some exterior chips and scratches                                       4
# some creases on seats                                                   4
# some chips around the exterior                                          4
# a lemon squad pre-purchase inspection is included with this listing.    3
# some chips around exterior some creases on seats                        3
# some creases on the driver's seat                                       3
# 2019 date codes on tires                                                2
# some scratches on the exterior some creases on seats                    2
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 4087
# Most frequent: some chips on the front end
# ------------------------------
#
# ### Column: Recent Service History ###
# Top 10 Value Counts:
# Recent Service History
# some service history is detailed in the attached carfax report.                                                                                                                                   9
# some service history is detailed in the attached carfax history report.                                                                                                                           8
# the seller reports that the following services have been performed in preparation for the sale: engine oil and filter changed                                                                     4
# the seller reports that the following services have been performed: july 2025: engine oil and filter changed                                                                                      4
# the selling dealer reports that the following services have been performed: november 2025: engine oil and filter changed additional service history is detailed in the attached carfax report.    3
# the selling dealer states that the engine oil and filter were recently changed.                                                                                                                   3
# the seller reports that the following services have been performed: september 2025: engine oil and filter changed                                                                                 3
# the seller reports that the following services have been performed: december 2024: engine oil and filter changed                                                                                  3
# the seller states that this g63 has not required service due to its low mileage.                                                                                                                  3
# the seller states that this rivian has not required service due to its low mileage.                                                                                                               3
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 4182
# Most frequent: some service history is detailed in the attached carfax report.
# ------------------------------
#
# ### Column: Ownership History ###
# Top 10 Value Counts:
# Ownership History
# the selling dealer reportedly acquired this 911 earlier in 2025.                                                             4
# the selling dealer reportedly acquired this range rover in october 2025.                                                     3
# the selling dealer reportedly acquired this cayenne earlier in 2025.                                                         3
# the selling dealer reports that they acquired this bmw earlier in 2025.                                                      3
# the selling dealer reportedly acquired this x5 in november 2025.                                                             3
# the selling dealer reportedly acquired this cayenne in november 2025.                                                        3
# the selling dealer reports that they acquired this range rover in september 2025.                                            3
# the seller reportedly acquired this v8 vantage in june 2024.                                                                 2
# the selling dealer reports that they acquired this boxster in november 2025 and have added approximately 200 miles since.    2
# the seller reportedly purchased this tesla new in june 2022.                                                                 2
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 4195
# Most frequent: the selling dealer reportedly acquired this 911 earlier in 2025.
# ------------------------------
#
# ### Column: Other Items Included in Sale ###
# Top 10 Value Counts:
# Other Items Included in Sale
# 2 keys owner's manual                    248
# 1 key                                    178
# 1 key owner's manual                     162
# 2 keys                                   145
# 2 keys owner's manual window sticker      71
# 2 keys owner's manuals                    66
# 2 keys owner's manual service records     40
# 1 key owner's manuals                     25
# 2 keys owner’s manual                     23
# 2 keys service records                    18
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 2939
# Most frequent: 2 keys owner's manual
# ------------------------------
#
# ### Column: Seller Notes ###
# Top 10 Value Counts:
# Seller Notes
# there is a loan on this vehicle, and sale proceeds will be used to satisfy the loan. we recommend handling the loan payoff securely through cars & bids safepay if agreed to by both the buyer and the seller. please note that the title may only be available after the loan has been paid off.                                                          136
# vintage vehicles may not carry emissions equipment, and exemptions to emissions and safety testing vary from state to state. as always, it's the buyer's responsibility to perform all due diligence regarding registering this car in their respective state prior to placing a bid.                                                                       26
# the seller reports that the windows have been tinted.                                                                                                                                                                                                                                                                                                       21
# the seller states that the windows are tinted.                                                                                                                                                                                                                                                                                                              21
# the selling dealer will collect sales tax from florida buyers, as well as states that have state tax reciprocity agreements with florida.                                                                                                                                                                                                                   18
# the seller notes that the windows are tinted.                                                                                                                                                                                                                                                                                                               17
# the selling dealer charges a $65 documentation fee to the winning bidder.                                                                                                                                                                                                                                                                                   17
# there is a loan on this vehicle, and sale proceeds will be used to satisfy the loan. we recommend handling the loan payoff securely through cars & bids safepay if agreed to by both the buyer and the seller. please note that the title may only be available after the loan has been paid off. the seller reports that the windows have been tinted.     12
# the seller reports that the windows of this bmw have been tinted.                                                                                                                                                                                                                                                                                           11
# the selling dealer states that the windows are tinted.                                                                                                                                                                                                                                                                                                       8
# Name: count, dtype: int64
#
# Categorical Distribution:
# Unique values: 2803
# Most frequent: there is a loan on this vehicle, and sale proceeds will be used to satisfy the loan. we recommend handling the loan payoff securely through cars & bids safepay if agreed to by both the buyer and the seller. please note that the title may only be available after the loan has been paid off.
# ------------------------------
#
# ### Column: Gears ###
# Top 10 Value Counts:
# Gears
# 6.0     1420
# 5.0      851
# 8.0      681
# 7.0      495
# 4.0      468
# 3.0       78
# 10.0      76
# 9.0       64
# 2.0        3
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4136.000000
# mean        6.077369
# std         1.430303
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# ------------------------------
#
# ### Column: Engine_Displacement_L ###
# Top 10 Value Counts:
# Engine_Displacement_L
# 3.0    642
# 2.0    399
# 4.0    253
# 5.0    217
# 2.5    199
# 6.2    176
# 3.6    146
# 3.2    129
# 4.4    123
# 5.7     99
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4003.000000
# mean        3.735024
# std         1.417082
# min         1.000000
# 25%         2.700000
# 50%         3.500000
# 75%         4.700000
# max         9.300000
# ------------------------------
#
# ### Column: is_single_owner ###
# Top 10 Value Counts:
# is_single_owner
# 0    4317
# 1       2
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.000463
# std         0.021517
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: 2_keys_ind ###
# Top 10 Value Counts:
# 2_keys_ind
# 1    2764
# 0    1555
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.639963
# std         0.480066
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# ------------------------------
#
# ### Column: is_dry_climate_car ###
# Top 10 Value Counts:
# is_dry_climate_car
# 0    3073
# 1    1246
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.288493
# std         0.453114
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# ------------------------------
#
# ### Column: has_full_service_records ###
# Top 10 Value Counts:
# has_full_service_records
# 0    4277
# 1      42
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.009724
# std         0.098143
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: is_no_reserve ###
# Top 10 Value Counts:
# is_no_reserve
# 0    4319
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# ------------------------------
#
# ### Column: is_all_original ###
# Top 10 Value Counts:
# is_all_original
# 0    4317
# 1       2
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.000463
# std         0.021517
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: is_numbers_matching ###
# Top 10 Value Counts:
# is_numbers_matching
# 0    4319
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# ------------------------------
#
# ### Column: is_project_car ###
# Top 10 Value Counts:
# is_project_car
# 0    4296
# 1      23
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.005325
# std         0.072789
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: has_new_tires ###
# Top 10 Value Counts:
# has_new_tires
# 0    4282
# 1      37
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.008567
# std         0.092170
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: has_sport_seats ###
# Top 10 Value Counts:
# has_sport_seats
# 0    4171
# 1     148
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.034267
# std         0.181936
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: emissions_ind ###
# Top 10 Value Counts:
# emissions_ind
# 0    2998
# 1    1321
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.305858
# std         0.460823
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# ------------------------------
#
# ### Column: loan_ind ###
# Top 10 Value Counts:
# loan_ind
# 0    3748
# 1     571
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.132207
# std         0.338754
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: one_owner_ind ###
# Top 10 Value Counts:
# one_owner_ind
# 0    3963
# 1     356
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.082426
# std         0.275045
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# ------------------------------
#
# ### Column: carfax_ind ###
# Top 10 Value Counts:
# carfax_ind
# 0    2946
# 1    1373
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        0.317898
# std         0.465713
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# ------------------------------
#
# ### Column: flaw_severity_score ###
# Top 10 Value Counts:
# flaw_severity_score
# 0     2915
# 5      948
# 10     154
# 40     130
# 50      53
# 45      34
# 15      34
# 55      23
# 90      10
# 20       5
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        4.466312
# std        11.699543
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         5.000000
# max       135.000000
# ------------------------------
#
# ### Column: recent_major_service ###
# Top 10 Value Counts:
# recent_major_service
# 1    4319
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# ------------------------------
#
# ### Column: auction_year ###
# Top 10 Value Counts:
# auction_year
# 2025    3212
# 2026    1107
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean     2025.256309
# std         0.436645
# min      2025.000000
# 25%      2025.000000
# 50%      2025.000000
# 75%      2026.000000
# max      2026.000000
# ------------------------------
#
# ### Column: auction_month ###
# Top 10 Value Counts:
# auction_month
# 10    920
# 9     838
# 11    709
# 12    679
# 1     633
# 2     474
# 8      66
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean        8.056958
# std         4.021422
# min         1.000000
# 25%         2.000000
# 50%        10.000000
# 75%        11.000000
# max        12.000000
# ------------------------------
#
# ### Column: car_age ###
# Top 10 Value Counts:
# car_age
# 9.0     191
# 19.0    187
# 10.0    176
# 12.0    174
# 7.0     167
# 11.0    166
# 8.0     158
# 4.0     156
# 13.0    144
# 6.0     140
# Name: count, dtype: int64
#
# Numeric Distribution:
# count    4319.000000
# mean       17.003705
# std        12.386006
# min         0.000000
# 25%         8.000000
# 50%        15.000000
# 75%        24.000000
# max       100.000000
# ------------------------------
#
# ### Column: Title Status_Bill of Sale ###
# Top 10 Value Counts:
# Title Status_Bill of Sale
# False    4309
# True       10
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4309
# ------------------------------
#
# ### Column: Title Status_CLean ###
# Top 10 Value Counts:
# Title Status_CLean
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Clean ###
# Top 10 Value Counts:
# Title Status_Clean
# True     4240
# False      79
# Name: count, dtype: int64
#
# Numeric Distribution:
# count     4319
# unique       2
# top       True
# freq      4240
# ------------------------------
#
# ### Column: Title Status_Clen ###
# Top 10 Value Counts:
# Title Status_Clen
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Exceeds Mechanical Limits ###
# Top 10 Value Counts:
# Title Status_Exceeds Mechanical Limits
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Lemon Law Buyback ###
# Top 10 Value Counts:
# Title Status_Lemon Law Buyback
# False    4317
# True        2
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4317
# ------------------------------
#
# ### Column: Title Status_Manufacturer Buyback ###
# Top 10 Value Counts:
# Title Status_Manufacturer Buyback
# False    4313
# True        6
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4313
# ------------------------------
#
# ### Column: Title Status_NAM, Rebuilt ###
# Top 10 Value Counts:
# Title Status_NAM, Rebuilt
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_No Title ###
# Top 10 Value Counts:
# Title Status_No Title
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Not Actual MIleage ###
# Top 10 Value Counts:
# Title Status_Not Actual MIleage
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Not Actual Mileage ###
# Top 10 Value Counts:
# Title Status_Not Actual Mileage
# False    4308
# True       11
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4308
# ------------------------------
#
# ### Column: Title Status_Odometer Discrepancy ###
# Top 10 Value Counts:
# Title Status_Odometer Discrepancy
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Prior Salvage ###
# Top 10 Value Counts:
# Title Status_Prior Salvage
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Rebuilt ###
# Top 10 Value Counts:
# Title Status_Rebuilt
# False    4307
# True       12
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4307
# ------------------------------
#
# ### Column: Title Status_Rebuilt Salvage ###
# Top 10 Value Counts:
# Title Status_Rebuilt Salvage
# False    4317
# True        2
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4317
# ------------------------------
#
# ### Column: Title Status_Rebuilt/Restored ###
# Top 10 Value Counts:
# Title Status_Rebuilt/Restored
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Rebuilt/Salvage ###
# Top 10 Value Counts:
# Title Status_Rebuilt/Salvage
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Reconstructed ###
# Top 10 Value Counts:
# Title Status_Reconstructed
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Reconstructed/Totaled ###
# Top 10 Value Counts:
# Title Status_Reconstructed/Totaled
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Title Status_Registered ###
# Top 10 Value Counts:
# Title Status_Registered
# False    4304
# True       15
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4304
# ------------------------------
#
# ### Column: Title Status_Salvage ###
# Top 10 Value Counts:
# Title Status_Salvage
# False    4314
# True        5
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4314
# ------------------------------
#
# ### Column: Title Status_Salvaged ###
# Top 10 Value Counts:
# Title Status_Salvaged
# False    4317
# True        2
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4317
# ------------------------------
#
# ### Column: Title Status_Totaled/Reconstructed ###
# Top 10 Value Counts:
# Title Status_Totaled/Reconstructed
# False    4318
# True        1
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4318
# ------------------------------
#
# ### Column: Seller Type_Private Party ###
# Top 10 Value Counts:
# Seller Type_Private Party
# True     3214
# False    1105
# Name: count, dtype: int64
#
# Numeric Distribution:
# count     4319
# unique       2
# top       True
# freq      3214
# ------------------------------
#
# ### Column: Drivetrain_Front-wheel drive ###
# Top 10 Value Counts:
# Drivetrain_Front-wheel drive
# False    4025
# True      294
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4025
# ------------------------------
#
# ### Column: Drivetrain_Rear-wheel drive ###
# Top 10 Value Counts:
# Drivetrain_Rear-wheel drive
# True     2162
# False    2157
# Name: count, dtype: int64
#
# Numeric Distribution:
# count     4319
# unique       2
# top       True
# freq      2162
# ------------------------------
#
# ### Column: Transmission_Type_Manual ###
# Top 10 Value Counts:
# Transmission_Type_Manual
# False    2711
# True     1608
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       2711
# ------------------------------
#
# ### Column: Body Style_Coupe ###
# Top 10 Value Counts:
# Body Style_Coupe
# False    3219
# True     1100
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       3219
# ------------------------------
#
# ### Column: Body Style_Hatchback ###
# Top 10 Value Counts:
# Body Style_Hatchback
# False    4132
# True      187
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4132
# ------------------------------
#
# ### Column: Body Style_SUV/Crossover ###
# Top 10 Value Counts:
# Body Style_SUV/Crossover
# False    3464
# True      855
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       3464
# ------------------------------
#
# ### Column: Body Style_Sedan ###
# Top 10 Value Counts:
# Body Style_Sedan
# False    3424
# True      895
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       3424
# ------------------------------
#
# ### Column: Body Style_Truck ###
# Top 10 Value Counts:
# Body Style_Truck
# False    4032
# True      287
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4032
# ------------------------------
#
# ### Column: Body Style_Van/Minivan ###
# Top 10 Value Counts:
# Body Style_Van/Minivan
# False    4256
# True       63
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4256
# ------------------------------
#
# ### Column: Body Style_Wagon ###
# Top 10 Value Counts:
# Body Style_Wagon
# False    4137
# True      182
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4137
# ------------------------------
#
# ### Column: Engine_Cylinders_I4 ###
# Top 10 Value Counts:
# Engine_Cylinders_I4
# False    3612
# True      707
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       3612
# ------------------------------
#
# ### Column: Engine_Cylinders_I5 ###
# Top 10 Value Counts:
# Engine_Cylinders_I5
# False    4262
# True       57
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4262
# ------------------------------
#
# ### Column: Engine_Cylinders_I6 ###
# Top 10 Value Counts:
# Engine_Cylinders_I6
# False    3727
# True      592
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       3727
# ------------------------------
#
# ### Column: Engine_Cylinders_V10 ###
# Top 10 Value Counts:
# Engine_Cylinders_V10
# False    4264
# True       55
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4264
# ------------------------------
#
# ### Column: Engine_Cylinders_V12 ###
# Top 10 Value Counts:
# Engine_Cylinders_V12
# False    4260
# True       59
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4260
# ------------------------------
#
# ### Column: Engine_Cylinders_V6 ###
# Top 10 Value Counts:
# Engine_Cylinders_V6
# False    3687
# True      632
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       3687
# ------------------------------
#
# ### Column: Engine_Cylinders_V8 ###
# Top 10 Value Counts:
# Engine_Cylinders_V8
# False    2789
# True     1530
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       2789
# ------------------------------
#
# ### Column: Engine_Cylinders_W12 ###
# Top 10 Value Counts:
# Engine_Cylinders_W12
# False    4295
# True       24
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4295
# ------------------------------
#
# ### Column: Engine_Cylinders_W8 ###
# Top 10 Value Counts:
# Engine_Cylinders_W8
# False    4317
# True        2
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       4317
# ------------------------------
#
# ### Column: mod_status_light_mod ###
# Top 10 Value Counts:
# mod_status_light_mod
# False    3120
# True     1199
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319
# unique        2
# top       False
# freq       3120
# ------------------------------
#
# ### Column: mod_status_unknown_mod ###
# Top 10 Value Counts:
# mod_status_unknown_mod
# True     2433
# False    1886
# Name: count, dtype: int64
#
# Numeric Distribution:
# count     4319
# unique       2
# top       True
# freq      2433
# ------------------------------
#
# ### Column: Model_Target_Encoded ###
# Top 10 Value Counts:
# Model_Target_Encoded
# 14074.381679    131
# 32332.500000    108
# 24773.395604     91
# 21137.777778     63
# 31074.763636     55
# 13033.890909     55
# 20235.769231     52
# 15080.176471     51
# 51092.595745     47
# 28669.288889     45
# Name: count, dtype: int64
#
# Numeric Distribution:
# count      4319.000000
# mean      30822.467006
# std       29658.975817
# min        2400.000000
# 25%       14074.381679
# 50%       22895.666667
# 75%       35516.312500
# max      475000.000000
# ------------------------------

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Load data
df = pd.read_csv("../data/cars_and_bids_full_history_v3.csv")
df.head()
# Out:
#                                                  URL  Sold_Price  Bids  \
# 0  https://carsandbids.com/auctions/rkdqRPJN/2026...    226000.0  21.0
# 1  https://carsandbids.com/auctions/30Op4L4g/2026...     76500.0  11.0
# 2  https://carsandbids.com/auctions/3010V6BV/2026...    215485.0  14.0
# 3  https://carsandbids.com/auctions/KZB8oVXk/2026...    356000.0  52.0
# 4  https://carsandbids.com/auctions/rxVbB5lO/bruc...         NaN  12.0
#
#      Views  Watchers               Auction_Date  \
# 0  19077.0       NaN  Feb 11, 2026 11:30 AM MST
# 1   9834.0       NaN    Feb 2, 2026 1:46 PM MST
# 2  12902.0       NaN   Jan 29, 2026 1:10 PM MST
# 3  40939.0       NaN    Jan 2, 2026 2:16 PM MST
# 4   6137.0       NaN   Dec 29, 2025 1:22 PM MST
#
#                                                 Make          Model Mileage  \
# 0                                      Mercedes-Benz  G Wagen\nSave      60
# 1                                                BMW   G8X M4\nSave   2,300
# 2                                      Mercedes-Benz  G Wagen\nSave     300
# 3                                            Porsche  992 911\nSave      70
# 4  THIS... is a charity auction for a Bruce Canep...            NaN     NaN
#
#   Title Status    Seller Type                       Engine  \
# 0   Clean (TX)  Private Party         4.0L Turbocharged V8
# 1   Clean (FL)  Private Party         3.0L Turbocharged I6
# 2   Clean (OH)  Private Party  4.0L Turbocharged Hybrid V8
# 3   Clean (AZ)         Dealer                  4.0L Flat-6
# 4          NaN            NaN                          NaN
#
#                                           Drivetrain  \
# 0                                            4WD/AWD
# 1                                   Rear-wheel drive
# 2                                            4WD/AWD
# 3                                   Rear-wheel drive
# 4  3-lap ride-alongs (1 ride-along each for the w...
#
#                                         Transmission     Body Style  \
# 0                                Automatic (9-Speed)  SUV/Crossover
# 1                                   Manual (6-Speed)          Coupe
# 2                                Automatic (9-Speed)  SUV/Crossover
# 3                                   Manual (6-Speed)          Coupe
# 4  All proceeds – including the Cars & Bids buyer...            NaN
#
#                   Exterior Color               Interior Color  \
# 0     Manufaktur Hyperblue Magno               Platinum White
# 1  Frozen Portimao Blue Metallic            Silverstone/Black
# 2                    Polar White  Manufaktur Red Pepper/Black
# 3                 Slate Grey Neo                        Black
# 4                            NaN                          NaN
#
#                  VIN              Location  \
# 0  W1NWH5AB6TX069473        Katy, TX 77450
# 1  WBS13HK00TCW00598   Hollywood, FL 33020
# 2  W1NWH5AB7TX063455       Mason, OH 45040
# 3  WP0AC2A92TS287032  Scottsdale, AZ 85255
# 4                NaN                   NaN
#
#                                           Highlights  \
# 0  THIS… is a 2026 Mercedes-AMG G63, finished in ...
# 1  THIS... is a 2026 BMW M4 Coupe, finished in Fr...
# 2  THIS… is a 2026 Mercedes-AMG G63, finished in ...
# 3  THIS... is a 2026 Porsche 911 GT3 Touring, fin...
# 4                                                NaN
#
#                                            Equipment Modifications  \
# 0  A build sheet is provided in the photo gallery...           NaN
# 1  A build sheet is provided in the gallery, and ...           NaN
# 2  A build sheet is provided in the photo gallery...           NaN
# 3  A build sheet is provided in the photo gallery...           NaN
# 4                                                NaN           NaN
#
#   Known Flaws                             Recent Service History  \
# 0         NaN  The seller states that this G63 has not requir...
# 1         NaN  The attached Carfax history report shows that ...
# 2         NaN  The seller states that this G63 has not requir...
# 3         NaN  The selling dealer states that this 911 has no...
# 4         NaN                                                NaN
#
#                                    Ownership History  \
# 0  The seller is representing this G63 on behalf ...
# 1  The seller reportedly purchased this M4 new in...
# 2  The seller reportedly purchased this G63 new i...
# 3  The selling dealer reportedly acquired this 91...
# 4                                                NaN
#
#                         Other Items Included in Sale  \
# 0                             2 keys Owner's manuals
# 1               2 keys Owner's manual Window sticker
# 2  2 keys Owner's manual Build sheet All-weather ...
# 3                  2 keys Owner's manual Build sheet
# 4                                                NaN
#
#                                         Seller Notes
# 0  There is a loan on this vehicle, and sale proc...
# 1  The seller states that clear paint protection ...
# 2  There is a loan on this vehicle, and sale proc...
# 3                                                NaN
# 4                                                NaN

# %%
# df['Interior Color'].value_counts()

# %%
import pandas as pd

def get_main_color(x):
    # 1. Catch missing values and group them into "Other"
    if pd.isna(x):
        return "Other"
        
    # 2. Grab the primary color before slashes or " and "
    x = str(x).split('/')[0].split(' and ')[0].strip()
    x_lower = x.lower()
    
    # 3. Check for specific keywords FIRST to prevent substring collisions 
    special_map = {
        # Edge cases, Collisions & Exterior Bleed-over
        'titanium': 'Gray', 'titan': 'Black', 'mustang': 'Brown', 'tanzanite': 'Blue',
        'stainless': 'Silver', 'mercury': 'Silver', 'magnetic': 'Gray', 'thunder': 'Gray',
        
        # Blacks / Darks
        'ebony': 'Black', 'nero': 'Black', 'carbon': 'Black', 'onyx': 'Black', 
        'jet': 'Black', 'obsidian': 'Black', 'beluga': 'Black', 'panther': 'Black',
        'amido': 'Black', 'midnight': 'Black', 'anthracite': 'Gray', 'zebra': 'Black',
        
        # Grays / Silvers
        'granite': 'Gray', 'charcoal': 'Gray', 'graphite': 'Gray', 'slate': 'Gray', 
        'ash': 'Gray', 'agate': 'Gray', 'stone': 'Gray', 'shale': 'Gray', 
        'platinum': 'Gray', 'pewter': 'Gray', 'palladium': 'Gray', 'meteor': 'Gray',
        'flint': 'Gray', 'ocean': 'Gray',
        
        # Whites / Lights
        'chalk': 'White', 'ivory': 'White', 'pearl': 'White', 'porcelain': 'White', 
        'alabaster': 'White', 'bianco': 'White', 'magnolia': 'White', 'oyster': 'White',
        'ice': 'White', 'ceramic': 'White',
        
        # Beiges / Tans / Browns
        'parchment': 'Beige', 'linen': 'Beige', 'cream': 'Beige', 'ecru': 'Beige', 
        'luxor': 'Beige', 'cashmere': 'Beige', 'savanna': 'Beige', 'almond': 'Beige', 
        'bamboo': 'Beige', 'wheat': 'Beige', 'champagne': 'Beige', 'kalahari': 'Beige', 
        'gobi': 'Beige', 'macchiato': 'Beige', 'taupe': 'Beige', 'sand': 'Beige', 
        'dune': 'Beige', 'saddle': 'Brown', 'oak': 'Brown', 'cocoa': 'Brown', 
        'cognac': 'Brown', 'caramel': 'Brown', 'cuoio': 'Brown', 'cinnamon': 'Brown', 
        'java': 'Brown', 'havanna': 'Brown', 'havana': 'Brown', 'mocha': 'Brown', 
        'espresso': 'Brown', 'nougat': 'Brown', 'chestnut': 'Brown', 'amaro': 'Brown', 
        'sepia': 'Brown', 'truffle': 'Brown', 'walnut': 'Brown', 'tartufo': 'Brown', 
        'terra': 'Brown', 'natural': 'Brown', 'palomino': 'Tan', 'camel': 'Tan', 
        'khaki': 'Tan', 'atacama': 'Tan',
        
        # Reds / Oranges
        'salsa': 'Red', 'coral': 'Red', 'imola': 'Red', 'fox': 'Red', 
        'burgundy': 'Red', 'magma': 'Red', 'carrera': 'Red', 'maroon': 'Red', 
        'chateau': 'Red', 'bordeaux': 'Red', 'fiona': 'Red', 'scarlet': 'Red', 
        'garnet': 'Red', 'crimson': 'Red', 'ruby': 'Red', 'cabernet': 'Red', 
        'rosso': 'Red', 'sakhir': 'Orange', 'kyalami': 'Orange',
        
        # Greens / Blues
        'jade': 'Green', 'cypress': 'Green', 'forest': 'Green', 'nordkap': 'Blue', 
        'nautic': 'Blue', 'yachting': 'Blue', 'estoril': 'Blue', 'marina': 'Blue'
    }
    
    for key, val in special_map.items():
        if key in x_lower:
            return val

    # 4. Check standard baseline colors
    std_colors = [
        'black', 'white', 'gray', 'grey', 'silver', 'red', 'blue', 
        'green', 'brown', 'beige', 'yellow', 'orange', 'gold', 'purple', 'tan'
    ]
    
    for color in std_colors:
        if color in x_lower:
            return 'Gray' if color == 'grey' else color.capitalize()
            
    # 5. Everything else becomes "Other"
    return "Other"

# 1. Apply the function to create a new cleaned column
df['Cleaned_Color'] = df['Interior Color'].apply(get_main_color)

df['Cleaned_Color_2'] = df['Exterior Color'].apply(get_main_color)

# 2. Calculate the percentage of rows marked as "Other"
total_rows = len(df)
other_count = (df['Cleaned_Color'] == 'Other').sum()
percentage_other = (other_count / total_rows) * 100

print(f"Total rows: {total_rows}")
print(f"Rows marked as 'Other': {other_count}")
print(f"Percentage 'Other': {percentage_other:.2f}%\n")

# 3. Inspect the top 20 original colors that are still slipping through
print("Top 20 original colors currently mapping to 'Other':")
slipping_through = df[df['Cleaned_Color'] == 'Other']['Interior Color'].value_counts()
print(slipping_through.head(20))
# Out:
# Total rows: 31137
# Rows marked as 'Other': 711
# Percentage 'Other': 2.28%
#
# Top 20 original colors currently mapping to 'Other':
# Interior Color
# Neutral                   19
# Saffron                   17
# Smoke Storm               16
# Custom                    11
# Auburn                    10
# Quartz                    10
# Umber/Light Tartufo       10
# Tahoe                     10
# Roast/Black               10
# Oatmeal                   10
# Biscuit                    9
# Mojave                     9
# Clark Plaid                8
# Arabica                    7
# Interlagos Plaid           7
# Navy Pier/Medium Slate     7
# Tobacco                    7
# Sepang                     7
# Mushroom                   7
# Cirrus/Ebony               7
# Name: count, dtype: int64

# %%
df['Cleaned_Color'] = df['Exterior Color'].apply(get_main_color)

# 2. Calculate the percentage of rows marked as "Other"
total_rows = len(df)
other_count = (df['Cleaned_Color'] == 'Other').sum()
percentage_other = (other_count / total_rows) * 100

print(f"Total rows: {total_rows}")
print(f"Rows marked as 'Other': {other_count}")
print(f"Percentage 'Other': {percentage_other:.2f}%\n")

# 3. Inspect the top 20 original colors that are still slipping through
print("Top 20 original colors currently mapping to 'Other':")
slipping_through = df[df['Cleaned_Color'] == 'Other']['Exterior Color'].value_counts()
print(slipping_through.head(20))
# Out:
# Total rows: 31137
# Rows marked as 'Other': 1179
# Percentage 'Other': 3.79%
#
# Top 20 original colors currently mapping to 'Other':
# Exterior Color
# Area 51                   18
# Grigio                    18
# Gun Metallic              15
# Techno Violet Metallic    15
# Lunar Mist Metallic       14
# Giallo Modena             14
# Umber Metallic            14
# Grigio Touring            14
# Argento Nurburgring       13
# Emerald Mica              13
# Macadamia Metallic        13
# Mahogany Metallic         13
# Hellrot                   12
# Caviar                    11
# Camouflage                10
# Absolute Zero             10
# Dark Sapphire             10
# Dark Cherry Metallic      10
# Grigio Alloy               9
# Go Mango                   9
# Name: count, dtype: int64

# %%
df["Cleaned_Color"].value_counts()
# Out:
# Cleaned_Color
# White     6572
# Black     6469
# Gray      4556
# Silver    3358
# Red       3254
# Blue      2963
# Other     1179
# Green     1128
# Yellow     465
# Beige      428
# Orange     287
# Brown      251
# Gold       100
# Tan         89
# Purple      38
# Name: count, dtype: int64
